# %% [markdown]
# <a href="https://colab.research.google.com/github/BobbyKKamawo/Machine-Learning-with-Python-Boot-Camp/blob/main/Orentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of Addition

# %%
A=2
B=3
C=A+B
print(C)
# Out:
# 5

# %% [markdown]
# Example of a String

# %%
Greetings= "What up doctor"
print (Greetings)
# Out:
# What up doctor
